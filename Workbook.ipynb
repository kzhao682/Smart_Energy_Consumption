# %%
from sqlalchemy import create_engine
import psycopg2
import pandas as pd

# %%
connection_string = 'postgresql://s7e4W8DOI4qG:9RNA82NdxDWc@dataport.cloud:5434/postgres'

# %%
conn = create_engine(connection_string)

# %%
pd.read_sql_query("""SELECT * FROM university.electricity_egauge_15min
                WHERE dataid=9737 AND local_15min BETWEEN '01-01-2013' AND '01-31-2013'""", conn)
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 87))
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/pool.py in _do_get(self)
#    1121             wait = use_overflow and self._overflow >= self._max_overflow
# -> 1122             return self._pool.get(wait, self._timeout)
#    1123         except sqla_queue.Empty:
#
# /usr/local/lib/python3.5/dist-packages/sqlalchemy/util/queue.py in get(self, block, timeout)
#     144                 if self._empty():
# --> 145                     raise Empty
#     146             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
pd.read_sql_query("""SELECT * FROM university.indoor_temperature_sensor as a
                WHERE dataid=7982""", conn)
# Out:
#         dataid                localminute  temp_f  temp_c
# 0         7982  2014-09-19 15:00:02-05:00   81.39   27.44
# 1         7982  2014-09-19 15:01:01-05:00   81.39   27.44
# 2         7982  2014-09-19 15:02:01-05:00   81.39   27.44
# 3         7982  2014-09-19 15:03:02-05:00   81.39   27.44
# 4         7982  2014-09-19 15:04:01-05:00   81.39   27.44
# 5         7982  2014-09-19 15:05:02-05:00   81.50   27.50
# 6         7982  2014-09-19 15:06:02-05:00   81.39   27.44
# 7         7982  2014-09-19 15:07:01-05:00   81.39   27.44
# 8         7982  2014-09-19 15:08:09-05:00   81.50   27.50
# 9         7982  2014-09-19 15:09:01-05:00   81.50   27.50
# 10        7982  2014-09-19 15:10:02-05:00   81.50   27.50
# 11        7982  2014-09-19 15:11:01-05:00   81.50   27.50
# 12        7982  2014-09-19 15:12:02-05:00   81.50   27.50
# 13        7982  2014-09-19 15:13:01-05:00   81.50   27.50
# 14        7982  2014-09-19 15:14:01-05:00   81.50   27.50
# ...

# %%
df_meta = pd.read_sql_query("""SELECT * FROM university.metadata WHERE city='Austin'""", conn)

# %%
df_meta = df_meta[['dataid', 'building_type', 'pv', 'house_construction_year', 'total_square_footage']]
df_meta = df_meta[(df_meta.total_square_footage > 0) & (df_meta.house_construction_year > 0)]

# %%
pd.read_sql_query("""SELECT DISTINCT a.latitude, a.longitude FROM university.weather as a""", conn)
# Out:
#     latitude   longitude
# 0  40.027278 -105.256111
# 1  30.292432  -97.699662
# 2  32.778033 -117.151885

# %%
#Weather of Austin, TX
weather_austin = pd.read_sql_query("""SELECT * FROM university.weather as a
                    WHERE localhour BETWEEN '01-01-2015 00:00:00' AND '01-01-2017 00:00:00'
                    AND latitude = '30.292432' """, conn)

# %%
#Weather of Boulder, CO
weather_boulder = pd.read_sql_query("""SELECT * FROM university.weather as a
                    WHERE localhour BETWEEN '01-01-2015 00:00:00' AND '01-01-2017 00:00:00'
                    AND latitude = '40.027278' """, conn)

# %%
#Weather of San Diego, CA
weather_sd = pd.read_sql_query("""SELECT * FROM university.weather as a
                    WHERE localhour BETWEEN '01-01-2015 00:00:00' AND '01-01-2017 00:00:00'
                    AND latitude = '32.778033' """, conn)

# %% [markdown]
# Selected dataid 4874 as initial building to test out

# %%
pd.read_sql_query("""SELECT DISTINCT a.dataid FROM university.electricity_egauge_hours as a""", conn)

# %%
df_4874 = pd.read_sql_query("""SELECT * FROM university.electricity_egauge_hours as a
                WHERE dataid=4874 AND localhour BETWEEN '04-01-2017' AND '05-01-2017'""", conn)
df_4874 = df_4874.sort_values('localhour', ascending=True)
df_4874

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
len(df_4874.localhour), len(df_4874.use)
# Out:
# (721, 721)

# %%
hours = range(len(df_4874.localhour))
hourly_usage = df_4874.use
plt.subplots(1,1,figsize=(20,6))
plt.plot(hours, hourly_usage)

# %%
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.5/dist-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# AR1

# %%
#hourly_usage must be converted to list
sm_AR1_model = sm.tsa.AR(hourly_usage.tolist(), freq="H").fit(maxlag=1)
print(sm_AR1_model.params)
# Out:
# [ 0.47880035  0.61355055]

# %%
x = df_4874.localhour
y_true = hourly_usage.tolist()

#plot actual usage
plt.subplots(1,1,figsize=(20,6))
plt.plot(x,y_true, label='actual usage')

x_pred = x[1:]
y_pred = sm_AR1_model.predict()

#plot model prediction with AR1
plt.plot(x_pred,y_pred, color='red', label='predicted usage')

plt.title("Electricity Usage of Building 4874 in April 2017 (AR1)")
plt.xlabel("Date")
plt.ylabel("Electricity Consumption (kWh)")
# plt.yscale('log')
plt.legend()

# %% [markdown]
# AR2

# %%
sm_AR2_model= sm.tsa.AR(hourly_usage.tolist(), freq="H").fit(maxlag=2)
print(sm_AR2_model.params)
# Out:
# [ 0.40461249  0.51627938  0.15749748]

# %%
x = df_4874.localhour
y_true = hourly_usage.tolist()

#plot actual usage
plt.subplots(1,1,figsize=(20,6))
plt.plot(x,y_true, label='actual usage')

x_pred = x[2:]
y_pred = sm_AR2_model.predict()

#plot model prediction with AR2
plt.plot(x_pred,y_pred, color='red', label='predicted usage')

plt.title("Electricity Usage of Building 4874 in April 2017 (AR2)")
plt.xlabel("Date")
plt.ylabel("Electricity Consumption (kWh)")
# plt.yscale('log')
plt.legend()

# %%
sm_AR3_model = sm.tsa.AR(hourly_usage.tolist(), freq="H").fit(maxlag=3)
print(sm_AR3_model.params)
# Out:
# [ 0.39371011  0.51121599  0.14169728  0.02995487]

# %%
x = df_4874.localhour
y_true = hourly_usage.tolist()

#plot actual usage
plt.subplots(1,1,figsize=(20,6))
plt.plot(x,y_true, label='actual usage')

x_pred = x[3:]
y_pred = sm_AR3_model.predict()

#plot model prediction with AR3
plt.plot(x_pred,y_pred, color='red', label='predicted usage')

plt.title("Electricity Usage of Building 4874 in April 2017 (AR3)")
plt.xlabel("Date")
plt.ylabel("Electricity Consumption (kWh)")
# plt.yscale('log')
plt.legend()

# %% [markdown]
# Moving Average (MA)

# %%
df_4874_new = pd.DataFrame(hourly_usage.tolist(), columns=["Hourly_Usage"])
df_4874_new["Hourly_Usage_MA10"] = pd.stats.moments.rolling_mean(df_4874_new, window=10, center=True)
df_4874_new.index = pd.to_datetime(df_4874['localhour'].dt.strftime('%Y-%m-%d %H:%M:%S'))
df_4874_new.head(20)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=True,window=10).mean()
#                      Hourly_Usage  Hourly_Usage_MA10
# localhour
# 2017-04-01 05:00:00      0.403800                NaN
# 2017-04-01 06:00:00      0.401900                NaN
# 2017-04-01 07:00:00      0.431317                NaN
# 2017-04-01 08:00:00      0.732233                NaN
# 2017-04-01 09:00:00      0.385033                NaN
# 2017-04-01 10:00:00      0.384283           0.537333
# 2017-04-01 11:00:00      0.517867           0.616062
# 2017-04-01 12:00:00      0.644200           0.680805
# 2017-04-01 13:00:00      0.495467           0.720332
# 2017-04-01 14:00:00      0.977233           0.714712
# 2017-04-01 15:00:00      1.191083           0.723570
# 2017-04-01 16:00:00      1.049333           0.732403
# ...

# %%
x = df_4874.localhour
y_true = hourly_usage.tolist()

#plot actual usage
plt.subplots(1,1,figsize=(20,6))
plt.plot(x,y_true, label='actual usage')

x_pred = x
y_pred = df_4874_new['Hourly_Usage_MA10']

#plot model prediction with AR3
plt.plot(x_pred,y_pred, color='red', label='predicted usage')

plt.title("Electricity Usage of Building 4874 in April 2017 (MA10)")
plt.xlabel("Date")
plt.ylabel("Electricity Consumption (kWh)")
# plt.yscale('log')
plt.legend()

# %%
ewma= pd.stats.moments.ewma(df_4874_new, halflife=5)
ewma.head(20)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.ewm(min_periods=0,ignore_na=False,halflife=5,adjust=True).mean()
#   """Entry point for launching an IPython kernel.
#                      Hourly_Usage  Hourly_Usage_MA10
# localhour
# 2017-04-01 05:00:00      0.403800                NaN
# 2017-04-01 06:00:00      0.402784                NaN
# 2017-04-01 07:00:00      0.413640                NaN
# 2017-04-01 08:00:00      0.510531                NaN
# 2017-04-01 09:00:00      0.478040                NaN
# 2017-04-01 10:00:00      0.456548           0.537333
# 2017-04-01 11:00:00      0.469329           0.579422
# 2017-04-01 12:00:00      0.503109           0.617994
# 2017-04-01 13:00:00      0.501721           0.649117
# 2017-04-01 14:00:00      0.583794           0.666099
# 2017-04-01 15:00:00      0.684276           0.679273
# ...

# %%
x = df_4874.localhour
y_true = hourly_usage.tolist()

#plot actual usage
plt.subplots(1,1,figsize=(20,6))
plt.plot(x,y_true, label='actual usage')

x_pred = x
y_pred = ewma['Hourly_Usage']

#plot model prediction with AR3
plt.plot(x_pred,y_pred, color='red', label='predicted usage')

plt.title("Electricity Usage of Building 4874 in April 2017 (EWMA)")
plt.xlabel("Date")
plt.ylabel("Electricity Consumption (kWh)")
# plt.yscale('log')
plt.legend()

# %% [markdown]
# ARIMA

# %%
import itertools
import seasonal
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(df_4874_new.Hourly_Usage, freq=24)
fig = plt.figure()
fig = decomposition.plot()
fig.set_size_inches(15,8)

# %%
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):

    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=24)
    rolstd = pd.rolling_std(timeseries, window=24)

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df_4874_new.Hourly_Usage)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=24).mean()
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=24).std()
# Results of Dickey-Fuller Test:
# Test Statistic                -8.760890e+00
# p-value                        2.676127e-14
# #Lags Used                     6.000000e+00
# Number of Observations Used    7.140000e+02
# Critical Value (10%)          -2.568930e+00
# Critical Value (5%)           -2.865596e+00
# Critical Value (1%)           -3.439542e+00
# dtype: float64

# %% [markdown]
# Original time series was already stationary

# %%
df_4874_new['first_difference'] = df_4874_new.Hourly_Usage - df_4874_new.Hourly_Usage.shift(1)
# test_stationarity(df_4874_new.first_difference)

# %%
df_4874_new['seasonal_difference'] = df_4874_new.Hourly_Usage - df_4874_new.Hourly_Usage.shift(24)
# test_stationarity(df_4874_new.seasonal_difference)

# %%
df_4874_new['seasonal_first_difference'] = df_4874_new.first_difference - df_4874_new.first_difference.shift(24)
# test_stationarity(df_4874_new.seasonal_first_difference)

# %% [markdown]
# PACF and ACF charts

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df_4874_new.seasonal_first_difference.iloc[25:], lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df_4874_new.seasonal_first_difference.iloc[25:], lags=40, ax=ax2)

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 24) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 24)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 24)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 24)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 24)

# %%
#apply gridsearch to find optimal parameters
def gridsearch_arima(y):
    
    low_aic = [0,0,50000]
    
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                model = sm.tsa.statespace.SARIMAX(y,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)
                results = model.fit()
                if results.aic < low_aic[2]:
                    low_aic = [param, param_seasonal, results.aic]

#                 print('ARIMA{}x{}24 - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue
    return low_aic

# %%
low_aic_1 = gridsearch_arima(y_true)
# Out:
# ARIMA(0, 0, 0)x(0, 0, 1, 24)24 - AIC:2182.4894806439065
# ARIMA(0, 0, 0)x(0, 1, 1, 24)24 - AIC:1436.5017448469982
# ARIMA(0, 0, 0)x(1, 0, 0, 24)24 - AIC:1815.3064536564998
# ARIMA(0, 0, 0)x(1, 0, 1, 24)24 - AIC:1493.5764481004576
# /usr/local/lib/python3.5/dist-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(0, 0, 0)x(1, 1, 0, 24)24 - AIC:1607.6804449091082
# ARIMA(0, 0, 0)x(1, 1, 1, 24)24 - AIC:1437.3760590073803
# ARIMA(0, 0, 1)x(0, 0, 0, 24)24 - AIC:2065.6579967128364
# ARIMA(0, 0, 1)x(0, 0, 1, 24)24 - AIC:1831.3183468648838
# ARIMA(0, 0, 1)x(0, 1, 0, 24)24 - AIC:1743.0153340042837
# ARIMA(0, 0, 1)x(0, 1, 1, 24)24 - AIC:1285.7909693419028
# ARIMA(0, 0, 1)x(1, 0, 0, 24)24 - AIC:1635.86322768204
# ARIMA(0, 0, 1)x(1, 0, 1, 24)24 - AIC:1346.98089634492
# ARIMA(0, 0, 1)x(1, 1, 0, 24)24 - AIC:1471.0938264737651
# ...

# %%
print(low_aic_1)
# Out:
# [(1, 0, 1), (0, 1, 1, 24), 1188.8014317250454]

# %% [markdown]
# ARIMA(1, 0, 1)x(0, 1, 1, 24)24 returned lowest AIC score of 1264.34

# %%
arima = sm.tsa.statespace.SARIMAX(y_true,
                                  trend='n',
                                  order=low_aic_1[0],
                                  seasonal_order=low_aic_1[1],
                                  enforce_stationarity=False,
                                  enforce_invertibility=False)
results = arima.fit()
print(results.summary())
# Out:
#                                  Statespace Model Results
# ...
# Dep. Variable:                                  y   No. Observations:                  721
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 24)   Log Likelihood                -590.401
# Date:                            Tue, 05 Sep 2017   AIC                           1188.801
# Time:                                    20:09:40   BIC                           1207.124
# Sample:                                         0   HQIC                          1195.874
#                                             - 721
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7698      0.037     21.027      0.000       0.698       0.842
# ma.L1         -0.3411      0.053     -6.429      0.000      -0.445      -0.237
# ...

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %% [markdown]
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html

# %% [markdown]
# ## Holt-Winters doesn't look like it works very well with this data...

# %%
seasons, trend = seasonal.fit_seasons(y_true)
adjusted = seasonal.adjust_seasons(y_true, seasons=seasons)
residual = adjusted - trend
plt.subplots(1,1, figsize=(15,6))
plt.plot(y_true, label='actual')
plt.plot(trend, label='trend')
plt.plot(residual, label='residual')
plt.legend()

# %% [markdown]
# ### Now, fit a model on training set

# %%
df_4874_train = df_4874_new.loc['2017-04-01 00:00:00':'2017-04-30 00:00:00', :]
df_4874_test = df_4874_new.loc['2017-04-30 01:00:00':,:]

# %%
df_4874_train['forecast'] = results.predict(start=646, end=694, dynamic=False)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_4874_train[['Hourly_Usage', 'forecast']].plot(figsize=(15,6))

# %% [markdown]
# Must add future time points before forecasting

# %%
from datetime import datetime
from dateutil.relativedelta import *

# %%
start = datetime.strptime("2017-04-30 01:00:00", "%Y-%m-%d %H:%M:%S")
date_list = [start + relativedelta(hours=x) for x in range(0,30)]
future = pd.DataFrame(index=date_list, columns= df_4874_train.columns)
df_4874_train = pd.concat([df_4874_train, future])

# %%
y_train = df_4874_train.Hourly_Usage
low_aic_2 = gridsearch_arima(y_train)

# %%
arima_1 = sm.tsa.statespace.SARIMAX(y_train,
                                  trend='n',
                                  order=low_aic_2[0],
                                  seasonal_order=low_aic_2[1],
                                  enforce_stationarity=False,
                                  enforce_invertibility=False)
results = arima_1.fit()

# %%
df_4874_train
# Out:
#                      Hourly_Usage  Hourly_Usage_MA10  first_difference  \
# 2017-04-01 05:00:00      0.403800                NaN               NaN
# 2017-04-01 06:00:00      0.401900                NaN         -0.001900
# 2017-04-01 07:00:00      0.431317                NaN          0.029417
# 2017-04-01 08:00:00      0.732233                NaN          0.300917
# 2017-04-01 09:00:00      0.385033                NaN         -0.347200
# 2017-04-01 10:00:00      0.384283           0.537333         -0.000750
# 2017-04-01 11:00:00      0.517867           0.616062          0.133583
# 2017-04-01 12:00:00      0.644200           0.680805          0.126333
# 2017-04-01 13:00:00      0.495467           0.720332         -0.148733
# 2017-04-01 14:00:00      0.977233           0.714712          0.481767
# 2017-04-01 15:00:00      1.191083           0.723570          0.213850
# 2017-04-01 16:00:00      1.049333           0.732403         -0.141750
# ...

# %%
df_4874_train['forecast'] = results.predict(start='2017-04-30 01:00:00', end='2017-05-01 05:00:00')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.DatetimeEngine.get_loc (pandas/_libs/index.c:9851)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:14031)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13975)()
#
# KeyError: 1493514000000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# ...

# %% [markdown]
# ## Clustering buildings

# %%
pd.set_option('display.max_columns', None)

# %%
df_metadata= pd.read_csv('dataport-metadata.csv')
df_metadata.head()
# Out:
#    dataid active_record       building_type program_579 program_baseline  \
# 0    2836           NaN  Single-Family Home         NaN              NaN
# 1    2743           NaN  Single-Family Home         NaN              NaN
# 2    5323           NaN  Single-Family Home         NaN              yes
# 3    8560           NaN  Single-Family Home         NaN              yes
# 4    3313           NaN  Single-Family Home         NaN              yes
#
#   program_energy_internet_demo program_lg_appliance program_verizon  \
# 0                          yes                  NaN             NaN
# 1                          yes                  NaN             NaN
# 2                          yes                  NaN             NaN
# 3                          yes                  NaN             NaN
# 4                          yes                  NaN             NaN
#
#   program_ccet_group program_civita_group    city  state   pv date_enrolled  \
# ...

# %%
df_metadata[(df_metadata.house_construction_year > 0) & 
            (df_metadata.total_square_footage > 0) &
           (df_metadata.city == 'Austin')]
# Out:
#       dataid active_record       building_type program_579 program_baseline  \
# 0       2836           NaN  Single-Family Home         NaN              NaN
# 1       2743           NaN  Single-Family Home         NaN              NaN
# 2       5323           NaN  Single-Family Home         NaN              yes
# 3       8560           NaN  Single-Family Home         NaN              yes
# 4       3313           NaN  Single-Family Home         NaN              yes
# 5       5052           NaN  Single-Family Home         NaN              yes
# 6       3936           NaN  Single-Family Home         NaN              yes
# 7       1622           NaN           Town Home         NaN              yes
# 8       1114           NaN  Single-Family Home         NaN              yes
# 9       5433           NaN  Single-Family Home         NaN              yes
# 10      1101           NaN  Single-Family Home         NaN              yes
# ...
